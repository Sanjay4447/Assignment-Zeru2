# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

wallets_df = pd.read_csv("C:\\Users\\sanja\Downloads\\Wallet id - Sheet1.csv")
wallets = wallets_df['wallet_id'].str.lower().tolist()

np.random.seed(42)
features_list = []

for i in wallets:
    sup = np.random.uniform(100, 10000)
    bor = np.random.uniform(0, sup * 0.9)
    ratio = bor / sup if sup > 0 else 0
    liq = np.random.poisson(0.5)
    bor_ev = np.random.randint(1, 10)
    repay = np.random.uniform(0.5, 1.0)
    col_div = np.random.randint(1, 5)

    features_list.append({
        'wallet_id': i,
        'sup': sup,
        'bor': bor,
        'ratio': ratio,
        'liq': liq,
        'bor_ev': bor_ev,
        'repay': repay,
        'col_div': col_div
    })

features_df = pd.DataFrame(features_list)

features = ['ratio', 'liq', 'repay', 'bor']
scaler = MinMaxScaler()
features_df[scoring_features] = scaler.fit_transform(features_df[features])
features_df['repay'] = 1 - features_df['repay']

weights = {
    'ratio': 0.4,
    'liq': 0.3,
    'repay': 0.2,
    'bor': 0.1
}

features_df['score'] = (
    features_df['ratio'] * weights['ratio'] +
    features_df['liq'] * weights['liq'] +
    features_df['repay'] * weights['repay'] +
    features_df['bor'] * weights['bor']
) * 1000

features_df['score'] = features_df['score'].round().astype(int)

output_df = features_df[['wallet_id', 'score']]
output_df.to_csv("wallet_risk_scores.csv", index=False)
output_df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\sanja\AppData\Local\Temp\ipykernel_5404\3289618612.py:5: SyntaxWarning: invalid escape sequence '\D'
#   wallets_df = pd.read_csv("C:\\Users\\sanja\Downloads\\Wallet id - Sheet1.csv")
#                                     wallet_id  score
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3    635
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988    425
# 2  0x0795732aacc448030ef374374eaae57d2965c16c    498
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9    319
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae    314
